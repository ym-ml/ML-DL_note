# %% [markdown]
# # 1. 机器学习概览

# %% [markdown]
# ## 1.1 数据不匹配

# %% [markdown]
# 当获取的大量数据中<span style="color:#6B8CBE;font-weight:600;font-size:15px">只有一小部分最符合实际部署模型后得到的数据</span>时,此时当然将最符合的数据用于测试与验证,但是在测试集上做K折交叉验证时,难以判断模型效果不好是因为过拟合还是数据不好.
# 此时需要从训练集中分出来一部分 **"train_dev集"** ,模型训练完成后在train_dev上进行评估,如果表现不佳,就一定是过拟合了.然后再在测试集上做K折交叉验证再次调参,最后在验证集上验证
